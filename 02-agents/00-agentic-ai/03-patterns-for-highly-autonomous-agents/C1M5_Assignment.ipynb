# %% [markdown]
# # Graded Lab: Agentic Workflows
#
# In this lab, you will build an agentic system that generates a short research report through planning, external tool usage, and feedback integration. Your workflow will involve:
#
# ### Agents
#
# * **Planning Agent / Writer**: Creates an outline and coordinates tasks.
# * **Research Agent**: Gathers external information using tools like Arxiv, Tavily, and Wikipedia.
# * **Editor Agent**: Reflects on the report and provides suggestions for improvement.

# %% [markdown]
# ---
# <a name='submission'></a>
#
# <h4 style="color:green; font-weight:bold;">TIPS FOR SUCCESSFUL GRADING OF YOUR ASSIGNMENT:</h4>
#
# * All cells are frozen except for the ones where you need to write your solution code or when explicitly mentioned you can interact with it.
#
# * In each exercise cell, look for comments `### START CODE HERE ###` and `### END CODE HERE ###`. These show you where to write the solution code. **Do not add or change any code that is outside these comments**.
#
# * You can add new cells to experiment but these will be omitted by the grader, so don't rely on newly created cells to host your solution code, use the provided places for this.
#
# * Avoid using global variables unless you absolutely have to. The grader tests your code in an isolated environment without running all cells from the top. As a result, global variables may be unavailable when scoring your submission. Global variables that are meant to be used will be defined in UPPERCASE.
#
# * To submit your notebook for grading, first save it by clicking the 💾 icon on the top left of the page and then click on the <span style="background-color: red; color: white; padding: 3px 5px; font-size: 16px; border-radius: 5px;">Submit assignment</span> button on the top right of the page.
# ---

# %% [markdown]
# ### Research Tools
#
# By importing `research_tools`, you gain access to several search utilities:
#
# - `research_tools.arxiv_search_tool(query)` → search academic papers from **arXiv**
#
#   *Example:* `research_tools.arxiv_search_tool("neural networks for climate modeling")`
#
# - `research_tools.tavily_search_tool(query)` → perform web searches with the **Tavily API**
#
#   *Example:* `research_tools.tavily_search_tool("latest trends in sunglasses fashion")`
#
# - `research_tools.wikipedia_search_tool(query)` → retrieve summaries from **Wikipedia**
#
#   *Example:* `research_tools.wikipedia_search_tool("Ensemble Kalman Filter")`
#
# Run the cell below to make them available.

# %%
# =========================
# Imports
# =========================

# --- Standard library 
from datetime import datetime
import re
import json
import ast


# --- Third-party ---
from IPython.display import Markdown, display
from aisuite import Client

# --- Local / project ---
import research_tools

# %%
import unittests

# %% [markdown]
# ### Initialize client
#
# Create a shared client instance for upcoming calls.

# %%
CLIENT = Client()

# %% [markdown]
# ## Exercise 1: planner_agent
#
# ### Objective
# Correctly set up a call to a language model (LLM) to generate a research plan.
#
# ### Instructions
#
# 1. **Focus Areas**:
#    - Ensure `CLIENT.chat.completions.create` is correctly configured.
#    - Pass the `model` and `messages` parameters correctly:
#      - **Model**: Use `"openai:o4-mini"` by default.
#      - **Messages**: Set with `{"role": "user", "content": user_prompt}`.
#      - **Temperature**: Fixed at 1 for creative outputs.
#
# ### Notes
#
# - The prompt is pre-defined and guides the LLM on task requirements.
# - Only return a formatted list of steps — no extra text.
#
# Focus on the LLM call setup to complete the task.

# %%
# GRADED FUNCTION: planner_agent

def planner_agent(topic: str, model: str = "openai:o4-mini") -> list[str]:
    """
    Generates a plan as a Python list of steps (strings) for a research workflow.

    Args:
        topic (str): Research topic to investigate.
        model (str): Language model to use.

    Returns:
        List[str]: A list of executable step strings.
    """

    
    # Build the user prompt
    user_prompt = f"""
    You are a planning agent responsible for organizing a research workflow with multiple intelligent agents.

    🧠 Available agents:
    - A research agent who can search the web, Wikipedia, and arXiv.
    - A writer agent who can draft research summaries.
    - An editor agent who can reflect and revise the drafts.

    🎯 Your job is to write a clear, step-by-step research plan **as a valid Python list**, where each step is a string.
    Each step should be atomic, executable, and must rely only on the capabilities of the above agents.

    🚫 DO NOT include irrelevant tasks like "create CSV", "set up a repo", "install packages", etc.
    ✅ DO include real research-related tasks (e.g., search, summarize, draft, revise).
    ✅ DO assume tool use is available.
    ✅ DO NOT include explanation text — return ONLY the Python list.
    ✅ The final step should be to generate a Markdown document containing the complete research report.

    Topic: "{topic}"
    """

    # Add the user prompt to the messages list
    messages = [{"role": "user", "content": user_prompt}]

    ### START CODE HERE ###

    # Call the LLM
    response = CLIENT.chat.completions.create( 
        # Pass in the model
        model=model,
        # Define the messages. Remember this is meant to be a user prompt!
        messages=messages,
        # Keep responses creative
        temperature=1, 
    )

    ### END CODE HERE ###

    # Extract message from response
    steps_str = response.choices[0].message.content.strip()

    # Parse steps
    steps = ast.literal_eval(steps_str)

    return steps

# %%
# Test your code!
unittests.test_planner_agent(planner_agent)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 2: research_agent
#
# ### Objective
# Set up a call to a language model (LLM) to perform a research task using various tools.
#
# ### Instructions
#
# **Focus Areas**:
#
# - **Creating a Custom Prompt**:
#   - **Define the Role**: Clearly specify the role, such as "research assistant."
#   - **List Available Tools** (as strings inside the prompt, not the actual functions):
#     - Use `arxiv_tool` to find academic papers.
#     - Use `tavily_tool` for general web searches.
#     - Use `wikipedia_tool` for accessing encyclopedic knowledge.
#   - **Specify the Task**: Include a placeholder in your prompt for defining the specific task that needs to be accomplished.
#   - **Include Date Information**: Add a placeholder for the current date or time to provide context.
#
# - **Creating Messages Dict**:
#   - Ensure the `messages` are correctly set with `{"role": "user", "content": prompt}`.
#
# - **Creating Tools List**:
#   - Create a list of tools for use, such as `research_tools.arxiv_search_tool`, `research_tools.tavily_search_tool`, and `research_tools.wikipedia_search_tool`.
#
# - **Correctly Setting the Call to the LLM**:
#   - Pass the `model`, `messages`, and `tools` parameters accurately.
#   - Set `tool_choice` to `"auto"` for automatic tool selection.
#   - Limit interactions with `max_turns=6`.
#
# ### Notes
#
# - The function provides pre-coded blocks where you need to replace placeholder values.
# - The approach allows the LLM to use tools dynamically based on the task.
#
# Focus on accurately setting the messages, tools, and LLM call parameters to complete the task.

# %%
# GRADED FUNCTION: research_agent

def research_agent(task: str, model: str = "openai:gpt-4o", return_messages: bool = False):
    """
    Executes a research task using tools via aisuite (no manual loop).
    Returns either the assistant text, or (text, messages) if return_messages=True.
    """
    print("==================================")  
    print("🔍 Research Agent")                 
    print("==================================")

    current_time = datetime.now().strftime('%Y-%m-%d')
    
    ### START CODE HERE ###

    # Create a customizable prompt by defining the role (e.g., "research assistant"),
    # listing tools (arxiv_tool, tavily_tool, wikipedia_tool) for various searches,
    # specifying the task with a placeholder, and including a current_time placeholder.
    prompt = f"""
    You are a highly capable research assistant, designed to help users accomplish complex tasks with accuracy and efficiency.

    You have access to the following tools to support your work:
    - arxiv_tool: for searching and retrieving academic papers and research insights
    - tavily_tool: for general web search and up-to-date information
    - wikipedia_tool: for background knowledge, definitions, and historical context

    Instructions:
    - Carefully analyze the user's request.
    - Decide which tool(s) are most relevant.
    - Use tools when necessary to gather accurate and current information.
    - Combine findings into a clear, structured, and helpful response.
    - Cite or reference sources when applicable.
    - If no tool is needed, respond directly using your knowledge.

    Task:
    {task}

    Context:
    - Current time: {current_time}

    Output requirements:
    - Provide a well-organized answer.
    - Use step-by-step reasoning when appropriate.
    - Be concise but informative.
    """
    
    # Create the messages dict to pass to the LLM. Remember this is a user prompt!
    messages = [{"role": "user", "content": prompt}]

    # Save all of your available tools in the tools list. These can be found in the research_tools module.
    # You can identify each tool in your list like this: 
    # research_tools.<name_of_tool>, where <name_of_tool> is replaced with the function name of the tool.
    tools = [research_tools.arxiv_search_tool, research_tools.tavily_search_tool, research_tools.wikipedia_search_tool]
    
    # Call the model with tools enabled
    response = CLIENT.chat.completions.create(  
        # Set the model
        model=model,
        # Pass in the messages. You already defined this!
        messages=messages,
        # Pass in the tools list. You already defined this!
        tools=tools,
        # Set the LLM to automatically choose the tools
        tool_choice="auto",
        # Set the max turns to 6
        max_turns=6
    )  
    
    ### END CODE HERE ###

    content = response.choices[0].message.content
    print("✅ Output:\n", content)

    
    return (content, messages) if return_messages else content

# %%
# Test your code!
unittests.test_research_agent(research_agent)
# Out:
# ==================================
# 🔍 Research Agent
# ==================================
# ✅ Output:
#  To accomplish the task of finding 3 key references and summarizing them briefly, I will utilize the following tools:
#
# 1. **arxiv_tool** to find recent and relevant academic papers.
# 2. **tavily_tool** to search for up-to-date information that may not be covered in academic literature.
# 3. **wikipedia_tool** to gather background information and context.
#
# Let's proceed by searching for relevant sources using these tools effectively. To determine the exact query for each tool, please specify the topic or area of interest for which you require the references and summaries.
# ==================================
# 🔍 Research Agent
# ==================================
# ✅ Output:
#  It seems there was an error retrieving information from the arXiv database. However, I can provide a brief summary of highly influential papers in machine learning and quantum computing from my existing knowledge:
#
# 1. **Machine Learning** - One of the most seminal papers is "Mastering the Game of Go with Deep Neural Networks and Tree Search" by David Silver et al., published in Nature in 2016. This paper discusses the development of AlphaGo, a computer program by DeepMind that defeated a professional human Go player. The significance of the paper lies in its demonstration of the capabilities of deep learning combined with strategic search algorithms in solving complex problems.
#
# 2. **Quantum Computing** - "Quantum Complexity Theory" by Ethan Bernstein and Umesh Vazirani, published in 1993, is a groundbreaking work in the field of quantum computing. The paper laid the foundation for quantum algorithms and defined the complexity class BQP (Bounded-error Quantum Polynomial time). It established the theoretical framework that guides the development of algorithms capable of solving problems more efficiently than classical computers under certain conditions.
#
# If you need more detailed information or access to specific papers, please let me know, and I can attempt to retrieve them again.
#  All tests passed!

# %% [markdown]
# ## Exercise 3: writer_agent
#
# ### Objective
# Set up a call to a language model (LLM) for executing writing tasks like drafting, expanding, or summarizing text.
#
# ### Instructions
#
# 1. **Focus Areas**:
#    - **System Prompt**:
#      - Define `system_prompt` to assign the LLM the role of a writing agent focused on generating academic or technical content.
#    - **System and User Messages**:
#      - Create `system_msg` using `{"role": "system", "content": system_prompt}`.
#      - Create `user_msg` using `{"role": "user", "content": task}`.
#    - **Messages List**:
#      - Combine `system_msg` and `user_msg` into a `messages` list.
#
# ### Notes
#
# - The function is designed to produce well-structured text by setting the correct prompts.
# - Temperature is set to 1.0 to allow for creative variance in the writing outputs.
#
# Ensure the system prompt and messages are defined properly to achieve a structured output from the LLM.

# %%
# GRADED FUNCTION: writer_agent
def writer_agent(task: str, model: str = "openai:gpt-4o") -> str: # @REPLACE def writer_agent(task: str, model: str = None) -> str:
    """
    Executes writing tasks, such as drafting, expanding, or summarizing text.
    """
    print("==================================")
    print("✍️ Writer Agent")
    print("==================================")

    ### START CODE HERE ###
    
    # Create the system prompt.
    # This should assign the LLM the role of a writing agent specialized in generating well-structured academic or technical content
    system_prompt = f"""You are an advanced writing agent specialized in producing high-quality academic and technical content.

    Your primary objective is to generate clear, well-structured, and rigorously reasoned text suitable for scholarly or professional contexts. You excel at organizing complex ideas into coherent narratives that follow logical progression and formal writing standards.

    Core responsibilities:
    - Produce structured outputs with clear sections (e.g., introduction, methodology, discussion, conclusion).
    - Maintain an objective, formal, and precise tone.
    - Use evidence-based reasoning and, when applicable, reference credible sources.
    - Ensure clarity, coherence, and logical flow between ideas.
    - Adapt the level of detail and technicality based on the task requirements.
    - Avoid ambiguity, unsupported claims, or informal language.

    Writing guidelines:
    - Prioritize accuracy, depth, and clarity over verbosity.
    - Break down complex concepts into understandable components.
    - Use appropriate terminology for the subject domain.
    - When relevant, include examples, definitions, or step-by-step explanations.
    - Format content using headings, bullet points, or numbered lists to enhance readability.

    Behavior rules:
    - Stay focused strictly on the assigned task.
    - Do not introduce irrelevant commentary.
    - If information is uncertain, acknowledge limitations rather than speculating.
    - Ensure the final output is polished, cohesive, and publication-ready.

    You will now perform the task provided by the user."""

    # Define the system msg by using the system_prompt and assigning the role of system
    system_msg = {"role": "system", "content": system_prompt}

    # Define the user msg. In this case the user prompt should be the task passed to the function
    user_msg = {"role": "user", "content": task}

    # Add both system and user messages to the messages list
    messages = [system_msg, user_msg]
    
    ### END CODE HERE ###

    response = CLIENT.chat.completions.create(
        model=model, 
        messages=messages,
        temperature=1.0
    )

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_writer_agent(writer_agent)
# Out:
# ==================================
# ✍️ Writer Agent
# ==================================
#  All tests passed!

# %% [markdown]
# ## Exercise 4: editor_agent
#
# ### Objective
# Configure a call to a language model (LLM) to perform editorial tasks such as reflecting, critiquing, or revising drafts.
#
# ### Instructions
#
# 1. **Focus Areas**:
#    - **System Prompt**:
#      - Define `system_prompt` to assign the LLM the role of an editor agent whose task is to reflect on, critique, or improve drafts.
#    - **System and User Messages**:
#      - Create `system_msg` using `{"role": "system", "content": system_prompt}`.
#      - Create `user_msg` using `{"role": "user", "content": task}`.
#    - **Messages List**:
#      - Combine `system_msg` and `user_msg` into a `messages` list.
#
# ### Notes
#
# - The editor agent is tailored for enhancing the quality of text by setting an appropriate role and task in the prompts.
# - Temperature is set to 0.7, balancing creativity and coherence in editorial outputs.
#
# Ensure the system prompt and messages are accurately set up to perform effective editorial tasks with the LLM.

# %%
# GRADED FUNCTION: editor_agent
def editor_agent(task: str, model: str = "openai:gpt-4o") -> str:
    """
    Executes editorial tasks such as reflection, critique, or revision.
    """
    print("==================================")
    print("🧠 Editor Agent")
    print("==================================")
    
    ### START CODE HERE ###

    # Create the system prompt.
    # This should assign the LLM the role of an editor agent specialized in reflecting on, critiquing, or improving existing drafts.
    system_prompt = f"""
    You are an expert editor agent specialized in reviewing, critiquing, and improving written drafts across academic, technical, and professional domains.

    Your primary goal is to enhance the clarity, coherence, structure, and overall quality of the provided text while preserving the author’s original intent.

    Core responsibilities:
    - Analyze the draft critically for structure, logic, and flow.
    - Identify strengths and weaknesses in the writing.
    - Provide constructive, actionable feedback for improvement.
    - Revise or rewrite sections to improve clarity, precision, and readability.
    - Ensure consistency in tone, terminology, and formatting.

    Editing guidelines:
    - Evaluate organization (introduction, body, conclusion, transitions).
    - Improve sentence clarity, grammar, and style.
    - Eliminate redundancy, ambiguity, and unnecessary complexity.
    - Strengthen arguments by improving logical flow and supporting details.
    - Adjust tone to match the intended audience (formal, academic, technical, etc.).
    - Maintain accuracy and avoid altering the original meaning.

    Output structure:
    1. **Summary of Assessment** – Brief overview of the draft’s quality and key issues.
    2. **Detailed Feedback** – Specific suggestions organized by category (structure, clarity, style, argumentation, etc.).
    3. **Revised Version** – An improved version of the text incorporating your recommendations.

    Behavior rules:
    - Be constructive and professional; avoid overly harsh or dismissive language.
    - Focus on improvement, not just criticism.
    - Do not introduce unrelated content.
    - Preserve the author’s voice where possible while improving quality.
    - If the draft is already strong, provide minor refinements and explain why.

    You will now review and improve the provided draft."""
    
    # Define the system msg by using the system_prompt and assigning the role of system
    system_msg = {"role": "system", "content": system_prompt}
    
    # Define the user msg. In this case the user prompt should be the task passed to the function
    user_msg = {"role": "user", "content": task}
    
    # Add both system and user messages to the messages list
    messages = [system_msg, user_msg]
    
    ### END CODE HERE ###
    
    response = CLIENT.chat.completions.create(
        model=model, 
        messages=messages,
        temperature=0.7 
    )
    
    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_editor_agent(editor_agent)
# Out:
# ==================================
# 🧠 Editor Agent
# ==================================
#  All tests passed!

# %% [markdown]
# ### 🎯 The Executor Agent
#
# The `executor_agent` manages the workflow by executing each step of a given plan. It:
#
# 1. Decides **which agent** (`research_agent`, `writer_agent`, or `editor_agent`) should handle the step.
# 2. Builds context from the outputs of previous steps.
# 3. Sends the enriched task to the selected agent.
# 4. Collects and stores the results in a shared history.
#
# 👉 **Do not implement or modify this function.** It is already provided as the orchestration component of the multi-agent pipeline.
#
# Notice that `planner_agent` might return a long list of steps. Because of this, the maximum number of steps is set to a maximum of 4 to keep running time reasonable.

# %%
agent_registry = {
    "research_agent": research_agent,
    "editor_agent": editor_agent,
    "writer_agent": writer_agent,
}

def clean_json_block(raw: str) -> str:
    """
    Clean the contents of a JSON block that may come wrapped with Markdown backticks.
    """
    raw = raw.strip()
    if raw.startswith("```"):
        raw = re.sub(r"^```(?:json)?\n?", "", raw)
        raw = re.sub(r"\n?```$", "", raw)
    return raw.strip()

# %%
def executor_agent(topic, model: str = "openai:gpt-4o", limit_steps: bool = True):

    plan_steps = planner_agent(topic)
    max_steps = 4

    if limit_steps:
        plan_steps = plan_steps[:min(len(plan_steps), max_steps)]
    
    history = []

    print("==================================")
    print("🎯 Editor Agent")
    print("==================================")

    for i, step in enumerate(plan_steps):

        agent_decision_prompt = f"""
        You are an execution manager for a multi-agent research team.

        Given the following instruction, identify which agent should perform it and extract the clean task.

        Return only a valid JSON object with two keys:
        - "agent": one of ["research_agent", "editor_agent", "writer_agent"]
        - "task": a string with the instruction that the agent should follow

        Only respond with a valid JSON object. Do not include explanations or markdown formatting.

        Instruction: "{step}"
        """
        response = CLIENT.chat.completions.create(
            model=model,
            messages=[{"role": "user", "content": agent_decision_prompt}],
            temperature=0,
        )

        raw_content = response.choices[0].message.content
        cleaned_json = clean_json_block(raw_content)
        agent_info = json.loads(cleaned_json)

        agent_name = agent_info["agent"]
        task = agent_info["task"]

        context = "\n".join([
            f"Step {j+1} executed by {a}:\n{r}" 
            for j, (s, a, r) in enumerate(history)
        ])
        enriched_task = f"""
        You are {agent_name}.

        Here is the context of what has been done so far:
        {context}

        Your next task is:
        {task}
        """

        print(f"\n🛠️ Executing with agent: `{agent_name}` on task: {task}")

        if agent_name in agent_registry:
            output = agent_registry[agent_name](enriched_task)
            history.append((step, agent_name, output))
        else:
            output = f"⚠️ Unknown agent: {agent_name}"
            history.append((step, agent_name, output))

        print(f"✅ Output:\n{output}")

    return history

# %%
# If you want to see the full workflow without limiting the number of steps. Set limit_steps to False
# Keep in mind this could take more than 10 minutes to complete
executor_history = executor_agent("The ensemble Kalman filter for time series forecasting", limit_steps=True)

md = executor_history[-1][-1].strip("`")  
display(Markdown(md))
# Out:
# ==================================
# 🎯 Editor Agent
# ==================================
#
# 🛠️ Executing with agent: `research_agent` on task: Search arXiv for papers on 'ensemble Kalman filter' and 'time series forecasting'
# ==================================
# 🔍 Research Agent
# ==================================
# ✅ Output:
#  It seems there were issues accessing the arXiv database to search for papers on "ensemble Kalman filter" and "time series forecasting." Here are some alternative steps we can take:
#
# 1. **Retry the search on arXiv:** We can attempt to search again after a short wait, as it might have been a temporary issue.
#
# 2. **Use Tavily Tool for additional searches:** Utilizing a broader web search might yield more information and references that include arXiv papers or other research articles.
#
# 3. **Consult academic databases or libraries:** If you have access to academic databases like IEEE Xplore, ScienceDirect, or Google Scholar, they can serve as excellent alternatives for finding related research papers.
#
# Please let me know how you wish to proceed, or if you have a preferred alternative.
# ✅ Output:
# It seems there were issues accessing the arXiv database to search for papers on "ensemble Kalman filter" and "time series forecasting." Here are some alternative steps we can take:
#
# 1. **Retry the search on arXiv:** We can attempt to search again after a short wait, as it might have been a temporary issue.
#
# 2. **Use Tavily Tool for additional searches:** Utilizing a broader web search might yield more information and references that include arXiv papers or other research articles.
#
# 3. **Consult academic databases or libraries:** If you have access to academic databases like IEEE Xplore, ScienceDirect, or Google Scholar, they can serve as excellent alternatives for finding related research papers.
#
# Please let me know how you wish to proceed, or if you have a preferred alternative.
#
# 🛠️ Executing with agent: `research_agent` on task: Collect definitions of 'Kalman filter' and 'ensemble Kalman filter' from Wikipedia
# ==================================
# 🔍 Research Agent
# ==================================
# ✅ Output:
#  It seems there was an issue accessing Wikipedia for definitions of "Kalman filter" and "ensemble Kalman filter." Let me provide a brief overview based on my existing knowledge:
#
# ### Kalman Filter
# The Kalman filter, named after Rudolf E. Kalman, is an algorithm that uses a series of measurements observed over time, containing statistical noise and other inaccuracies, to produce estimates of unknown variables. The goal is to minimize the mean of the squared errors (error covariance). It is widely used in control systems, robotics, and computer vision for tasks such as state estimation, prediction, and smoothing.
#
# ### Ensemble Kalman Filter (EnKF)
# The Ensemble Kalman Filter is an extension of the traditional Kalman filter. It was designed to handle the state estimation problems in high-dimensional systems, where the state space is too large for direct application of the traditional Kalman filter. The EnKF uses a Monte Carlo approach to represent the state with an ensemble of simulations. This allows it to approximate the forecast error covariance matrix using the ensemble instead of requiring a direct computation, which is particularly beneficial in complex systems such as weather forecasting.
#
# These definitions integrate general knowledge from the fields of statistics and state estimation. If you need more authoritative definitions or detailed descriptions, I recommend checking authoritative sources directly or if there are alternative ways to gather these details, such as through libraries or academic databases.
# ✅ Output:
# It seems there was an issue accessing Wikipedia for definitions of "Kalman filter" and "ensemble Kalman filter." Let me provide a brief overview based on my existing knowledge:
#
# ### Kalman Filter
# The Kalman filter, named after Rudolf E. Kalman, is an algorithm that uses a series of measurements observed over time, containing statistical noise and other inaccuracies, to produce estimates of unknown variables. The goal is to minimize the mean of the squared errors (error covariance). It is widely used in control systems, robotics, and computer vision for tasks such as state estimation, prediction, and smoothing.
#
# ### Ensemble Kalman Filter (EnKF)
# The Ensemble Kalman Filter is an extension of the traditional Kalman filter. It was designed to handle the state estimation problems in high-dimensional systems, where the state space is too large for direct application of the traditional Kalman filter. The EnKF uses a Monte Carlo approach to represent the state with an ensemble of simulations. This allows it to approximate the forecast error covariance matrix using the ensemble instead of requiring a direct computation, which is particularly beneficial in complex systems such as weather forecasting.
#
# These definitions integrate general knowledge from the fields of statistics and state estimation. If you need more authoritative definitions or detailed descriptions, I recommend checking authoritative sources directly or if there are alternative ways to gather these details, such as through libraries or academic databases.
#
# 🛠️ Executing with agent: `research_agent` on task: Gather state-of-the-art applications of the ensemble Kalman filter in time series forecasting from journal articles
# ==================================
# 🔍 Research Agent
# ==================================
# ✅ Output:
#  It appears that there were issues accessing both the arXiv database and Tavily search tool to gather information on the state-of-the-art applications of the ensemble Kalman filter in time series forecasting. Despite these setbacks, here's what I can suggest:
#
# ### Current Approach to Ensemble Kalman Filter Applications:
#
# 1. **Retry Searches Later:**
#    - Given that tool access might be temporarily unavailable, trying these searches again at a later time could yield results.
#
# 2. **Alternative Databases:**
#    - Exploring academic journals through databases such as IEEE Xplore, ScienceDirect, and Google Scholar might be beneficial. These platforms often have extensive collections of peer-reviewed articles that could cover the latest applications.
#
# 3. **Contact Academic Institutions:**
#    - If you have access to a university library, they often have subscriptions to multiple research databases that could provide comprehensive resources.
#
# 4. **Utilize Network and Forums:**
#    - Engaging with academic networks or platforms like ResearchGate may provide direct access to authors working on relevant research topics.
#
# While I could not provide direct articles or findings due to tool limitations, these strategies can help you gather the necessary information through alternative methods. If there's anything more specific you'd need guidance on, such as accessing a particular database or any other aspect, feel free to ask!
# ✅ Output:
# It appears that there were issues accessing both the arXiv database and Tavily search tool to gather information on the state-of-the-art applications of the ensemble Kalman filter in time series forecasting. Despite these setbacks, here's what I can suggest:
#
# ### Current Approach to Ensemble Kalman Filter Applications:
#
# 1. **Retry Searches Later:**
#    - Given that tool access might be temporarily unavailable, trying these searches again at a later time could yield results.
#
# 2. **Alternative Databases:**
#    - Exploring academic journals through databases such as IEEE Xplore, ScienceDirect, and Google Scholar might be beneficial. These platforms often have extensive collections of peer-reviewed articles that could cover the latest applications.
#
# 3. **Contact Academic Institutions:**
#    - If you have access to a university library, they often have subscriptions to multiple research databases that could provide comprehensive resources.
#
# 4. **Utilize Network and Forums:**
#    - Engaging with academic networks or platforms like ResearchGate may provide direct access to authors working on relevant research topics.
#
# While I could not provide direct articles or findings due to tool limitations, these strategies can help you gather the necessary information through alternative methods. If there's anything more specific you'd need guidance on, such as accessing a particular database or any other aspect, feel free to ask!
# 🛠️ Executing with agent: `research_agent` on task: Extract algorithmic details and equations for the ensemble Kalman filter from a representative paper
# ==================================
# 🔍 Research Agent
# ==================================
# ✅ Output:
#  Due to the persistent issues with accessing arXiv, I used a broader web search and found a relevant article discussing the ensemble Kalman filter. The paper titled "Penalized ensemble Kalman filters for high dimensional non-linear systems" provides an abstract overview of the EnKF as a data assimilation technique. You can access the full paper for comprehensive details on algorithmic structures and equations through the [National Center for Biotechnology Information (NCBI) website](https://pmc.ncbi.nlm.nih.gov/articles/PMC7971544/).
#
# ### Steps to Extract Algorithmic Details:
# 1. **Access the Paper:**
#    - Visit the provided link to read the full article.
#
# 2. **Review Abstract and Introduction:**
#    - Start by understanding the abstract and introduction, which usually provide an overview of the problem addressed and the methods applied.
#
# 3. **Focus on Methodology Section:**
#    - This section will contain the detailed algorithmic steps, including any mathematical equations and methodologies used in implementing the ensemble Kalman filter.
#
# 4. **Analyze Equations:**
#    - Pay attention to the equations provided, especially concerning state estimation and error covariance.
#
# 5. **Conclusion and Results:**
#    - Evaluate the conclusion and discussion about the effectiveness and applications of the penalized ensemble Kalman filter in high-dimensional systems.
#
# By following these steps, you should be able to extract detailed algorithmic insights from the paper. If you have access to specific academic databases or libraries, I recommend searching for related terms to find additional resources that might provide alternative explanations or additional perspectives.
# ✅ Output:
# Due to the persistent issues with accessing arXiv, I used a broader web search and found a relevant article discussing the ensemble Kalman filter. The paper titled "Penalized ensemble Kalman filters for high dimensional non-linear systems" provides an abstract overview of the EnKF as a data assimilation technique. You can access the full paper for comprehensive details on algorithmic structures and equations through the [National Center for Biotechnology Information (NCBI) website](https://pmc.ncbi.nlm.nih.gov/articles/PMC7971544/).
#
# ### Steps to Extract Algorithmic Details:
# 1. **Access the Paper:**
#    - Visit the provided link to read the full article.
#
# 2. **Review Abstract and Introduction:**
#    - Start by understanding the abstract and introduction, which usually provide an overview of the problem addressed and the methods applied.
#
# 3. **Focus on Methodology Section:**
#    - This section will contain the detailed algorithmic steps, including any mathematical equations and methodologies used in implementing the ensemble Kalman filter.
#
# 4. **Analyze Equations:**
#    - Pay attention to the equations provided, especially concerning state estimation and error covariance.
#
# 5. **Conclusion and Results:**
#    - Evaluate the conclusion and discussion about the effectiveness and applications of the penalized ensemble Kalman filter in high-dimensional systems.
#
# By following these steps, you should be able to extract detailed algorithmic insights from the paper. If you have access to specific academic databases or libraries, I recommend searching for related terms to find additional resources that might provide alternative explanations or additional perspectives.
# Due to the persistent issues with accessing arXiv, I used a broader web search and found a relevant article discussing the ensemble Kalman filter. The paper titled "Penalized ensemble Kalman filters for high dimensional non-linear systems" provides an abstract overview of the EnKF as a data assimilation technique. You can access the full paper for comprehensive details on algorithmic structures and equations through the [National Center for Biotechnology Information (NCBI) website](https://pmc.ncbi.nlm.nih.gov/articles/PMC7971544/).
#
# ### Steps to Extract Algorithmic Details:
# 1. **Access the Paper:**
#    - Visit the provided link to read the full article.
#
# 2. **Review Abstract and Introduction:**
#    - Start by understanding the abstract and introduction, which usually provide an overview of the problem addressed and the methods applied.
#
# 3. **Focus on Methodology Section:**
#    - This section will contain the detailed algorithmic steps, including any mathematical equations and methodologies used in implementing the ensemble Kalman filter.
#
# 4. **Analyze Equations:**
#    - Pay attention to the equations provided, especially concerning state estimation and error covariance.
#
# 5. **Conclusion and Results:**
#    - Evaluate the conclusion and discussion about the effectiveness and applications of the penalized ensemble Kalman filter in high-dimensional systems.
#
# By following these steps, you should be able to extract detailed algorithmic insights from the paper. If you have access to specific academic databases or libraries, I recommend searching for related terms to find additional resources that might provide alternative explanations or additional perspectives.

# %% [markdown]
# ## Check grading feedback
#
# If you have collapsed the right panel to have more screen space for your code, as shown below:
#
# <img src="./images/collapsed.png" alt="Collapsed Image" width="800" height="400"/>
#
# You can click on the left-facing arrow button (highlighted in red) to view feedback for your submission after submitting it for grading. Once expanded, it should display like this:
#
# <img src="./images/expanded.png" alt="Expanded Image" width="800" height="400"/>
